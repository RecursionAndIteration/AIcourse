# %% [markdown]
# <a href="https://colab.research.google.com/github/RecursionAndIteration/AIcourse/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist

(x_train, y_train), _=mnist.load_data()
fig,axes=plt.subplots(nrows=10,ncols=5,figsize=(7,14))
rng=np.random.default_rng()

for digit in range(10):
  idxs=np.where(y_train==digit)[0]
  chosen=rng.choice(idxs,size=5,replace=False)

  for col,img_idx in enumerate(chosen):
    ax=axes[digit,col]
    ax.imshow(x_train[img_idx],cmap="gray")
    ax.axis("off")
plt.show()

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
import numpy as np

(x_train, y_train),(x_test,y_test)=mnist.load_data()
x_train=x_train.astype("float32")/255.0
x_test=x_test.astype("float32")/255.0

x_train=x_train[...,np.newaxis]
x_test=x_test[...,np.newaxis]

y_train=to_categorical(y_train,10)
y_test=to_categorical(y_train,10)

# %%
import tensorflow as tf
from tensorflow.keras import layers, Sequential
from tensorflow.keras.utils import to_categorical # Added for correct y_test processing
from tensorflow.keras.datasets import mnist # Added to re-load original y_test

model=Sequential([
    layers.Flatten(input_shape=(28,28,1)),
    layers.Dense(512,activation="relu"),
    layers.Dropout(0.3),
    layers.Dense(256,activation="relu"),
    layers.Dropout(0.3),
    layers.Dense(10,activation="softmax")
])

model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])

# Correcting y_test for validation and evaluation
# Reloading mnist to get the original y_test labels (y_test_raw)
(_, _), (_, y_test_raw) = mnist.load_data()
y_test_corrected = to_categorical(y_test_raw, 10)

history=model.fit(x_train,y_train,batch_size=32,epochs=10,validation_data=(x_test,y_test_corrected))
loss,accuracy=model.evaluate(x_test,y_test_corrected)
print(f"strata {loss:.4f}, dokladnosc {accuracy:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.8716 - loss: 0.4079 - val_accuracy: 0.9640 - val_loss: 0.1103
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.9622 - loss: 0.1258 - val_accuracy: 0.9749 - val_loss: 0.0792
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.9721 - loss: 0.0915 - val_accuracy: 0.9747 - val_loss: 0.0812
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - accuracy: 0.9754 - loss: 0.0790 - val_accuracy: 0.9773 - val_loss: 0.0778
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9784 - loss: 0.0695 - val_accuracy: 0.9765 - val_loss: 0.0773
# Epoch 6/10
# ...

# %%
from pathlib import Path
from PIL import Image, ImageOps

for path in Path("testowe").rglob("*.png"):
  image=Image.open(path).convert('L')
  image=ImageOps.invert(image)
  image=image.resize((28,28))
  image=np.array(image).reshape(1,28,28,1)/255.0

  plt.imshow(image.reshape(28,28),cmap="gray")
  plt.title("przetworzony obrazek")
  plt.show()

  prediction=model.predict(image)
  digit=np.argmax(prediction)
  print(f"rozpoznana cyfra {digit}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# rozpoznana cyfra 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# rozpoznana cyfra 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# rozpoznana cyfra 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# rozpoznana cyfra 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# rozpoznana cyfra 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# rozpoznana cyfra 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# rozpoznana cyfra 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# rozpoznana cyfra 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# rozpoznana cyfra 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# rozpoznana cyfra 5
